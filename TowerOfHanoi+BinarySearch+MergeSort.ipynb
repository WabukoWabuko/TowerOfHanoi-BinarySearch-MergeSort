# %%
def binary_search(arr, low, high, x):
    if high >= low:
        mid = (high + low) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]
        merge_sort(left_half)
        merge_sort(right_half)
        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

def tower_of_hanoi(n, from_rod, to_rod, aux_rod):
    if n == 1:
        print("Move disk 1 from rod", from_rod, "to rod", to_rod)
        return
    tower_of_hanoi(n-1, from_rod, aux_rod, to_rod)
    print("Move disk", n, "from rod", from_rod, "to rod", to_rod)
    tower_of_hanoi(n-1, aux_rod, to_rod, from_rod)

while True:
    print("\nMenu:")
    print("1. Binary Search")
    print("2. Merge Sort")
    print("3. Tower of Hanoi")
    print("4. Exit")
    choice = int(input("Enter your choice: "))
    if choice == 1:
        arr = list(map(int, input("Enter the array (space-separated): ").split()))
        x = int(input("Enter the element to search: "))
        result = binary_search(arr, 0, len(arr)-1, x)
        if result != -1:
            print("Element is present at index", result)
        else:
            print("Element is not present in the array")
    elif choice == 2:
        arr = list(map(int, input("Enter the array (space-separated): ").split()))
        merge_sort(arr)
        print("Sorted array:", arr)
    elif choice == 3:
        n = int(input("Enter the number of disks: "))
        tower_of_hanoi(n, 'A', 'C', 'B')
    elif choice == 4:
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# Menu:
# 1. Binary Search
# 2. Merge Sort
# 3. Tower of Hanoi
# 4. Exit
# Enter your choice: 1
# Enter the array (space-separated): 2 4 5 86 12 00 34 67 49 99
# Enter the element to search: 0
# Element is not present in the array
#
# Menu:
# 1. Binary Search
# 2. Merge Sort
# 3. Tower of Hanoi
# 4. Exit
# Enter your choice: 2
# Enter the array (space-separated): 1 76 34 65 1 0 34
# Sorted array: [0, 1, 1, 34, 34, 65, 76]
#
# Menu:
# 1. Binary Search
# 2. Merge Sort
# 3. Tower of Hanoi
# 4. Exit
# Enter your choice: 3
# Enter the number of disks: 2
# Move disk 1 from rod A to rod B
# Move disk 2 from rod A to rod C
# Move disk 1 from rod B to rod C
#
# Menu:
# 1. Binary Search
# 2. Merge Sort
# 3. Tower of Hanoi
# 4. Exit
